# %% [markdown]
# # YouTube Premium Japan Q1 2020
#
# ## Selection of Exposed Markets for MMT
#
# ### Approach
#
# Get demo/DAVs/etc. for each population
# Based on audience
#  1. Heavy YouTube Users (HYU) / Core and Emerging Users
#  2. 18-54, 18-34 preferred
#  3. Slight skew for males
# Rank markets, applying more weight to HYU and Age?
#
# Bryan mentioned acquisition of HYU users.
# Priority will be on raw number of HYU users in a prefecture.

# %% [markdown]
# #### Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from authenticator import Authenticator
from sheetmanager import SheetManager

# %% [markdown]
# #### Initialize necessary strings

# %%
keys = 'credentials.json'
SCOPES = ['https://www.googleapis.com/auth/drive.readonly']

spreadsheetId = '1QbkOSgaHt75LeQY2a9GeUjHajXIHWv3Z-ID7svUPG6w'
dav_data_range = 'JP'
cce_data_range = 'CCE Split - JP by region!A2:D50'
pop_data_range = 'Population by Prefecture!O5:Q52'
age_data_range = 'Population by Prefecture by Age Group!B5:Y53'

su_spreadsheetId = '1LaRfoYATost1I7O0yhIrtY9pFZ7cDbGdp-G1TIHYaYs'
su_data_range = 'Sheet1'
su_date_start = '2018-11-23'
su_date_end = '2019-11-23'

# %% [markdown]
# #### Authenticate and Initialize Manager to work with Google Sheets

# %%
authenticator = Authenticator(keys)
creds = authenticator.get_creds(SCOPES)
manager = SheetManager(creds)

# %% [markdown]
# #### Load in data from G sheets as pandas dataframes

# %%
# load in the dav figures
dav_df = manager.get_values(sheetId=spreadsheetId,
                            data_range=dav_data_range,
                            )

dav_df = dav_df[dav_df['region_name'] != 'null']
dav_df['date'] = pd.to_datetime(dav_df['date'], format='%Y%m%d')
dav_df = dav_df.set_index('region_name')

r_df = dav_df.reset_index()[['date', 'region_name', 'total']]
r_df.to_csv('dav_data.csv', index=False, encoding='utf-8-sig')
#r_df.to_csv('dav_data.csv', index=False)
r_df.head()
# Out:
#         date        region_name    total
# 0 2019-09-27   Aichi Prefecture  3304533
# 1 2019-09-27   Akita Prefecture   230200
# 2 2019-09-27  Aomori Prefecture   318274
# 3 2019-09-27   Chiba Prefecture  1979841
# 4 2019-09-27   Ehime Prefecture   381356

# %%
# load in the cce split
cce_df = manager.get_values(sheetId=spreadsheetId,
                                data_range=cce_data_range,
                                as_df=True)

cce_df = cce_df[cce_df['region_name'] != 'null']
cce_df = cce_df.set_index('region_name')

# %%
# load in pop figures
pop_df = manager.get_values(sheetId=spreadsheetId,
                           data_range=pop_data_range)

pop_df = pop_df.set_index('region_name')

# %%
# load in age figures

age_df = manager.get_values(sheetId=spreadsheetId,
                           data_range=age_data_range)

age_df = age_df[age_df['Prefecture in EN'] != 'Total']
age_df = age_df.set_index('Prefecture in EN')

# we only want 18-54

age_df = age_df[['15～19歳', '20～24歳', '25～29歳', '30～34歳', '35～39歳', '40～44歳', '45～49歳', '50～54歳']]
age_df = age_df.rename(columns={'15～19歳': '15-19',
                                '20～24歳': '20-24',
                                '25～29歳': '25-29',
                                '30～34歳': '30-34',
                                '35～39歳': '35-39',
                                '40～44歳': '40-44',
                                '45～49歳': '45-49',
                                '50～54歳': '50-54'})

# %% [markdown]
# #### Read in the Sign-up Data and clean it
#  Then export it out as a csv for the R script

# %%
su_df = manager.get_values(sheetId=su_spreadsheetId,
                          data_range=su_data_range)

su_df['Day'] = pd.to_datetime(su_df['Day'])
# filter for time period
su_df = su_df[(su_df['Day'] >= su_date_start) & (su_df['Day'] <= su_date_end)]

# save as csv for the R script
su_df.to_csv('signups.csv', index=False)

fig = plt.figure(num=None,
                    figsize=(15, 10))
ax = fig.gca()

sns.lineplot(x='Day', y='Signups', hue='Region', data=su_df, ax=ax)

# %% [markdown]
# #### Pivot the DAV table so that index is the regions

# %%
#dav_df = dav_df.pivot_table(values=['unique_logged_in_dav', 'unique_visitor_dav', 'total'],
#                            index='region_name',
#                            columns='date')

table = dav_df.pivot_table(values=['unique_logged_in_dav', 'unique_visitor_dav', 'total'],
                            index='region_name',
                            aggfunc=np.mean)

# %% [markdown]
# #### Merge all dataframes together so that we have data by region in one dataframe

# %%
df = table.merge(cce_df, how='outer', left_index=True, right_index=True)
df = df.merge(pop_df, how='outer', left_index=True, right_index=True)
df = df.merge(age_df, how='outer', left_index=True, right_index=True)
df = df.rename(columns={'total': 'Average Total DAV',
               'unique_logged_in_dav': 'Average Unique Logged in DAV',
               'unique_visitor_dav': 'Average Unique Visitor DAV',
               'Casual': 'Casual Users Proportion',
               'Core': 'Core Users Proportion',
               'Emerging': 'Emerging Users Proportion',})

#df['Internet Population'] = df['General Populations'] * df['Internet Penetration (%)'] / 100
#df['YT penetration (of internet)'] = df['Average Total DAV'] / df['Internet Population']
#df['YT penetration (of population)'] = df['Average Total DAV'] / df['General Populations']
df['15-34'] = df['15-19'] + df['20-24'] + df['25-29'] + df['30-34']
df['HYU DAV'] = df['Average Total DAV'] * df['Core Users Proportion']
df['Internet Population'] = (df['Internet Penetration (%)']/100) * df['General Populations']

# order by Gen Pop and then get cumulative numbers

df = df.sort_values('HYU DAV', ascending=False)

df['HYU DAV (Cumulative)'] = df['HYU DAV'].cumsum()
df['HYU DAV (Cumulative) %'] = df['HYU DAV (Cumulative)']/df['HYU DAV'].sum()*100

df['Internet Population (Cumulative)'] = df['Internet Population'].cumsum()
df['Internet Population (Cumulative) %'] = df['Internet Population (Cumulative)']/df['Internet Population'].sum()*100

df['General Population (Cumulative)'] = df['General Populations'].cumsum()
df['General Population (Cumulative) %'] = df['General Population (Cumulative)']/df['General Populations'].sum()*100

# rename index to get rid of the funny characters
print('Old Index:')
print(df.index.tolist())

new_index = ['Tokyo', 'Osaka Prefecture', 'Kanagawa Prefecture', 'Aichi Prefecture', 'Saitama Prefecture',
             'Chiba Prefecture', 'Hokkaido Prefecture', 'Fukuoka Prefecture', 'Hyogo Prefecture', 'Shizuoka Prefecture',
             'Ibaraki Prefecture', 'Kyoto Prefecture', 'Hiroshima Prefecture', 'Miyagi Prefecture', 'Niigata Prefecture',
             'Tochigi Prefecture', 'Gunma Prefecture', 'Gifu Prefecture', 'Nagano Prefecture', 'Okayama Prefecture',
             'Fukushima Prefecture', 'Mie Prefecture', 'Kumamoto Prefecture', 'Okinawa Prefecture', 'Shiga Prefecture',
             'Nara Prefecture', 'Ehime Prefecture', 'Kagoshima Prefecture', 'Yamaguchi Prefecture', 'Aomori Prefecture',
             'Nagasaki Prefecture', 'Ishikawa Prefecture', 'Oita Prefecture', 'Miyazaki Prefecture', 'Iwate Prefecture',
             'Toyama Prefecture', 'Yamagata Prefecture', 'Kagawa Prefecture', 'Wakayama Prefecture', 'Yamanashi Prefecture',
             'Fukui Prefecture', 'Akita Prefecture', 'Tokushima Prefecture', 'Saga Prefecture', 'Kochi Prefecture',
             'Shimane Prefecture', 'Tottori Prefecture']

df.index = pd.Index(new_index)

df
# Out:
# Old Index:
# ['Tokyo', 'Osaka Prefecture', 'Kanagawa Prefecture', 'Aichi Prefecture', 'Saitama Prefecture', 'Chiba Prefecture', 'Hokkaido Prefecture', 'Fukuoka Prefecture', 'Hyōgo Prefecture', 'Shizuoka Prefecture', 'Ibaraki Prefecture', 'Kyoto Prefecture', 'Hiroshima Prefecture', 'Miyagi Prefecture', 'Niigata Prefecture', 'Tochigi Prefecture', 'Gunma Prefecture', 'Gifu Prefecture', 'Nagano Prefecture', 'Okayama Prefecture', 'Fukushima Prefecture', 'Mie Prefecture', 'Kumamoto Prefecture', 'Okinawa Prefecture', 'Shiga Prefecture', 'Nara Prefecture', 'Ehime Prefecture', 'Kagoshima Prefecture', 'Yamaguchi Prefecture', 'Aomori Prefecture', 'Nagasaki Prefecture', 'Ishikawa Prefecture', 'Ōita Prefecture', 'Miyazaki Prefecture', 'Iwate Prefecture', 'Toyama Prefecture', 'Yamagata Prefecture', 'Kagawa Prefecture', 'Wakayama Prefecture', 'Yamanashi Prefecture', 'Fukui Prefecture', 'Akita Prefecture', 'Tokushima Prefecture', 'Saga Prefecture', 'Kōchi Prefecture', 'Shimane Prefecture', 'Tottori Prefecture']
#                       Average Total DAV  Average Unique Logged in DAV  \
# Tokyo                      1.194657e+07                  7.634264e+06
# Osaka Prefecture           6.948709e+06                  4.386765e+06
# Kanagawa Prefecture        5.234163e+06                  3.289547e+06
# Aichi Prefecture           3.213150e+06                  1.929695e+06
# Saitama Prefecture         2.375264e+06                  1.435249e+06
# Chiba Prefecture           1.935724e+06                  1.168856e+06
# Hokkaido Prefecture        1.830390e+06                  1.155868e+06
# Fukuoka Prefecture         1.733438e+06                  1.058270e+06
# Hyogo Prefecture           1.677650e+06                  9.730610e+05
# Shizuoka Prefecture        1.106536e+06                  6.468867e+05
# Ibaraki Prefecture         8.529897e+05                  5.151290e+05
# Kyoto Prefecture           9.642305e+05                  5.747263e+05
# Hiroshima Prefecture       8.042648e+05                  4.705825e+05
# Miyagi Prefecture          6.552578e+05                  3.989755e+05
# Tokyo                   867  ...   1005   3293  2.898603e+06
# Osaka Prefecture        486  ...    608   1854  1.596954e+06
# Kanagawa Prefecture     518  ...    679   1960  1.211590e+06
# Aichi Prefecture        420  ...    507   1659  8.030780e+05
# Saitama Prefecture      405  ...    508   1536  6.264006e+05
# Chiba Prefecture        323  ...    428   1266  5.102926e+05
# Hokkaido Prefecture     235  ...    344    962  4.937186e+05
# Fukuoka Prefecture      275  ...    311   1052  4.552751e+05
# Hyogo Prefecture        267  ...    367   1060  4.328879e+05
# Shizuoka Prefecture     150  ...    241    680  3.083865e+05
# Ibaraki Prefecture      132  ...    185    554  2.448846e+05
# Kyoto Prefecture        159  ...    167    554  2.337131e+05
# Hiroshima Prefecture    136  ...    175    554  2.170582e+05
# Miyagi Prefecture       123  ...    144    481  1.854339e+05
# Niigata Prefecture       92  ...    141    400  1.831093e+05
# Tochigi Prefecture       83  ...    125    372  1.705036e+05
# Gunma Prefecture         90  ...    127    374  1.668406e+05
# Gifu Prefecture          92  ...    128    377  1.633534e+05
# Nagano Prefecture        79  ...    133    361  1.581691e+05
# Okayama Prefecture       97  ...    112    379  1.512164e+05
# Fukushima Prefecture     73  ...    117    336  1.498471e+05
# Mie Prefecture           82  ...    118    342  1.474660e+05
# Kumamoto Prefecture      75  ...    104    326  1.341067e+05
# Okinawa Prefecture       72  ...     89    317  1.298989e+05
# Shiga Prefecture         74  ...     89    298  1.298648e+05
# Nara Prefecture          66  ...     88    254  1.074039e+05
# Ehime Prefecture         52  ...     83    234  1.064936e+05
# Kagoshima Prefecture     62  ...     96    281  1.050148e+05
# Yamaguchi Prefecture     57  ...     80    239  9.942194e+04
# Aomori Prefecture        48  ...     83    213  9.496320e+04
# Nagasaki Prefecture      51  ...     82    232  9.259916e+04
# Ishikawa Prefecture      57  ...     71    225  9.242289e+04
# Oita Prefecture          47  ...     66    203  8.891830e+04
# Miyazaki Prefecture      41  ...     62    186  8.526417e+04
# Iwate Prefecture         47  ...     78    213  8.526300e+04
# Toyama Prefecture        44  ...     65    188  8.258117e+04
# Yamagata Prefecture      40  ...     66    187  8.189700e+04
# Kagawa Prefecture        40  ...     58    174  7.876333e+04
# Wakayama Prefecture      36  ...     60    162  7.619978e+04
# Yamanashi Prefecture     38  ...     56    153  6.778404e+04
# Fukui Prefecture         33  ...     48    145  6.628727e+04
# Akita Prefecture         30  ...     59    145  6.619415e+04
# Tokushima Prefecture     29  ...     45    128  6.315375e+04
# Saga Prefecture          35  ...     48    154  5.850742e+04
# Kochi Prefecture         26  ...     41    116  5.452089e+04
# Shimane Prefecture       25  ...     38    116  5.045030e+04
# Tottori Prefecture       22  ...     33    100  3.846149e+04
#
#                       Internet Population  HYU DAV (Cumulative)  \
# Tokyo                           12132.016          2.898603e+06
# Osaka Prefecture                 7473.081          4.495557e+06
# Kanagawa Prefecture              7739.355          5.707147e+06
# Aichi Prefecture                 6208.125          6.510225e+06
# Chiba Prefecture                              41.660353
# Hokkaido Prefecture                           45.858983
# Fukuoka Prefecture                            49.889510
# Hyogo Prefecture                              54.232566
# Shizuoka Prefecture                           57.132936
# Ibaraki Prefecture                            59.415349
# Kyoto Prefecture                              61.466521
# Hiroshima Prefecture                          63.699214
# Miyagi Prefecture                             65.532563
# Niigata Prefecture                            67.321716
# Tochigi Prefecture                            68.866212
# Gunma Prefecture                              70.413076
# Gifu Prefecture                               71.997822
# Nagano Prefecture                             73.636234
# Okayama Prefecture                            75.141270
# Fukushima Prefecture                          76.626574
# Mie Prefecture                                78.047164
# Kumamoto Prefecture                           79.440130
# Okinawa Prefecture                            80.578969
# Shiga Prefecture                              81.694131
# Nara Prefecture                               82.757995
# Ehime Prefecture                              83.834486
# Kagoshima Prefecture                          85.117751
# Yamaguchi Prefecture                          86.209237
# Aomori Prefecture                             87.217855
# Nagasaki Prefecture                           88.286454
# Ishikawa Prefecture                           89.191685
# Oita Prefecture                               90.100862
# Miyazaki Prefecture                           90.960318
# Iwate Prefecture                              91.950784
# Toyama Prefecture                             92.784197
# Yamagata Prefecture                           93.653913
# Kagawa Prefecture                             94.417085
# Wakayama Prefecture                           95.162894
# Yamanashi Prefecture                          95.812419
# Fukui Prefecture                              96.427218
# Akita Prefecture                              97.213278
# Tokushima Prefecture                          97.799665
# Saga Prefecture                               98.449979
# Kochi Prefecture                              99.013480
# Shimane Prefecture                            99.554093
# Tottori Prefecture                           100.000000
#
# [47 rows x 25 columns]

# %% [markdown]
# Find the markets we want to expose the ads to based on HYUs (and utilize all the budget, AKA 70ish % of HYU Pop), then find the best controls for those

# %%
exposed_markets = df[df['HYU DAV (Cumulative) %'] < 71].index.tolist()
print(len(exposed_markets), 'Exposed Markets:', exposed_markets)
# Out:
# 11 Exposed Markets: ['Tokyo', 'Osaka Prefecture', 'Kanagawa Prefecture', 'Aichi Prefecture', 'Saitama Prefecture', 'Chiba Prefecture', 'Hokkaido Prefecture', 'Fukuoka Prefecture', 'Hyogo Prefecture', 'Shizuoka Prefecture', 'Ibaraki Prefecture']

# %% [markdown]
# ### Load in the market match results

# %% [markdown]
# #### Need to select best controls for our selected exposed markets above
#
# These are the approved guidelines:
# 1. Within the top 30 percentile for lowest dynamic time warped distance
# 2. Market pair correlation of >90%
# 3. Mean correlation with other markets >50%
#
# 1st approach:
# 1. Select top 70% HYU DAV prefectures to be exposed
# 2. Find the best controls for these prefectures, adding up to about 10% of internet pop
#
#
#
# 2st approach:
# 1. Find the best controls that add up to around 10% of internet pop
# 2. Find the best matches for these controls that add up to 70% or HYU DAV
#
# Decision maker:
# 1. Is one big prefecture easier to reach than many small prefectures? e.g. One prefecture with 800k HYUs vs 4 prefectures with 200k HYUs each, or one 800k vs eight 100ks
# 2. If one big is better, go for Approach 1, else approach 2

# %% [markdown]
# #### Approach 1

# %%
mm_df = pd.read_csv('MM_results.csv')
mm_df = mm_df[['Region', 'ComparedRegion', 'rank', 'RelativeDistance', 'Correlation']]

a1_mm_df = mm_df[mm_df['Region'].isin(exposed_markets)]
a1_mm_df = a1_mm_df[~a1_mm_df['ComparedRegion'].isin(exposed_markets)]

a1_mm_df = a1_mm_df[(a1_mm_df['Correlation'] > .85)]

a1_mm_df = a1_mm_df.sort_values(['Region', 'Correlation', 'RelativeDistance'], ascending=[True, False, True])

#print(a1_mm_df)
#print(len(a1_mm_df['Region'].unique()))

print(a1_mm_df['ComparedRegion'].value_counts())

#approved_correlation = .9
#approved_distance = mm_df['RelativeDistance'].quantile(0.3)
#print('Distance must be lower than:', approved_distance)
#print('Correlation must be higher than:', approved_correlation)

# filter
#mm_df = mm_df[mm_df['RelativeDistance'] <= approved_distance]
#mm_df = mm_df[mm_df['Correlation'] > approved_correlation]
#print(mm_df)

# check if the mean correlation with the above filter is

#mm_table = mm_df.pivot_table(values=['Correlation', 'RelativeDistance'], index='Region', aggfunc=np.median)
#mm_table = mm_table.sort_values('Correlation', ascending=False)
#mm_table
# Out:
# Kyoto Prefecture        11
# Hiroshima Prefecture    11
# Miyagi Prefecture       11
# Nagano Prefecture       11
# Tochigi Prefecture      11
# Fukushima Prefecture    10
# Okayama Prefecture      10
# Niigata Prefecture       9
# Gunma Prefecture         9
# Kumamoto Prefecture      8
# Gifu Prefecture          8
# Mie Prefecture           7
# Aomori Prefecture        6
# Okinawa Prefecture       5
# Shiga Prefecture         4
# Nara Prefecture          2
# Iwate Prefecture         1
# Name: ComparedRegion, dtype: int64

# %% [markdown]
# #### Approach 2

# %%
mm_df = pd.read_csv('MM_results.csv')
mm_df = mm_df[['Region', 'ComparedRegion', 'rank', 'RelativeDistance', 'Correlation']]

# follow correlation and distance guidelines as far as possible
a2_mm_df = mm_df[(mm_df['Correlation'] > .9) & (mm_df['RelativeDistance'] < mm_df['RelativeDistance'].quantile(.3))]
print(a2_mm_df)
control_regions = a2_mm_df['Region'].unique().tolist()

# check third guideline of mean correlation
print(mm_df[mm_df['Region'].isin(control_regions)].pivot_table(values='Correlation',
                                                                    index='Region',
                                                                   aggfunc=np.mean).sort_values('Correlation', ascending=False))

print()

# let's check the % of gen pop if we use these control regions
for count in range(len(control_regions)):
    if count != 0:
        print(control_regions[:count], ':')
        print(df.filter(items=control_regions[:count], axis=0)['Internet Population'].sum()/df['Internet Population'].sum())

# looks like ['Aichi Prefecture', 'Chiba Prefecture'] for 11%
# ['Aichi Prefecture', 'Chiba Prefecture', 'Fukuoka Prefecture', 'Hokkaido Prefecture'] for 19%
# Out:
#                    Region       ComparedRegion  rank  RelativeDistance  \
# 0        Aichi Prefecture   Saitama Prefecture     1          0.257493
# 1        Aichi Prefecture     Chiba Prefecture     2          0.472418
# 2        Aichi Prefecture  Hokkaido Prefecture     3          0.562723
# 138      Chiba Prefecture  Hokkaido Prefecture     1          0.146239
# 139      Chiba Prefecture   Saitama Prefecture     2          0.276730
# 140      Chiba Prefecture   Fukuoka Prefecture     3          0.321102
# 141      Chiba Prefecture     Hyogo Prefecture     4          0.504563
# 276    Fukuoka Prefecture     Hyogo Prefecture     1          0.196230
# 277    Fukuoka Prefecture  Hokkaido Prefecture     2          0.310871
# 278    Fukuoka Prefecture     Chiba Prefecture     3          0.415632
# 506   Hokkaido Prefecture     Chiba Prefecture     1          0.155528
# 507   Hokkaido Prefecture   Fukuoka Prefecture     2          0.255422
# 508   Hokkaido Prefecture   Saitama Prefecture     3          0.390260
# 509   Hokkaido Prefecture     Hyogo Prefecture     4          0.427666
# 552      Hyogo Prefecture   Fukuoka Prefecture     1          0.227916
# 555      Hyogo Prefecture  Hokkaido Prefecture     4          0.604554
# 828   Kanagawa Prefecture     Osaka Prefecture     1          0.639418
# 1472     Osaka Prefecture  Kanagawa Prefecture     1          0.453440
# 1564   Saitama Prefecture     Chiba Prefecture     1          0.231860
# 1565   Saitama Prefecture  Hokkaido Prefecture     2          0.307453
# 1566   Saitama Prefecture     Aichi Prefecture     3          0.313147
# 1567   Saitama Prefecture   Fukuoka Prefecture     4          0.550886
#
#       Correlation
# 0        0.951454
# 1        0.946852
# 2        0.942210
# 138      0.929688
# 139      0.943407
# 140      0.927943
# 141      0.921975
# 276      0.920930
# 277      0.926536
# 278      0.927943
# 506      0.929688
# 507      0.926536
# 508      0.935648
# 509      0.920701
# 552      0.920930
# 555      0.920701
# 828      0.970127
# 1472     0.970127
# 1564     0.943407
# 1565     0.935648
# 1566     0.951454
# 1567     0.939394
#                      Correlation
# Region
# Kanagawa Prefecture     0.865172
# Aichi Prefecture        0.858293
# Saitama Prefecture      0.855533
# Osaka Prefecture        0.851899
# Fukuoka Prefecture      0.848388
# Chiba Prefecture        0.845348
# Hokkaido Prefecture     0.844068
# Hyogo Prefecture        0.837554
#
# ['Aichi Prefecture'] :
# 0.06146688662418469
# ['Aichi Prefecture', 'Chiba Prefecture'] :
# 0.11087855551130783
# ['Aichi Prefecture', 'Chiba Prefecture', 'Fukuoka Prefecture'] :
# 0.15021781839857173
# ['Aichi Prefecture', 'Chiba Prefecture', 'Fukuoka Prefecture', 'Hokkaido Prefecture'] :
# 0.1903023720819696
# ['Aichi Prefecture', 'Chiba Prefecture', 'Fukuoka Prefecture', 'Hokkaido Prefecture', 'Hyogo Prefecture'] :
# 0.23481695746562242
# ['Aichi Prefecture', 'Chiba Prefecture', 'Fukuoka Prefecture', 'Hokkaido Prefecture', 'Hyogo Prefecture', 'Kanagawa Prefecture'] :
# 0.31144461176209953
# ['Aichi Prefecture', 'Chiba Prefecture', 'Fukuoka Prefecture', 'Hokkaido Prefecture', 'Hyogo Prefecture', 'Kanagawa Prefecture', 'Osaka Prefecture'] :
# 0.3854358768478297

# %%
df = df.merge(mm_table, how='outer', left_index=True, right_index=True)

# %% [markdown]
# #### Get final ranking
#
# Exposed regions should be within

# %%
#df.to_csv('results.csv', encoding='utf-8-sig')
