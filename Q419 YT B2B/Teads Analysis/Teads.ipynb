# %%
import numpy as np
import pandas as pd
from statsmodels.stats.proportion import proportions_ztest as ztest

from authentication.authenticator import Authenticator
from sheets.sheetmanager import SheetManager

# %%
keys = 'credentials.json'
SCOPES = ['https://www.googleapis.com/auth/drive']

data_spreadsheetId = '1ZSZGAtYyGasHIbeCZYBvnN-Xv46hUs6-u5Larbqb0ag'
data_data_range = 'Teads Data'

codebook_spreadsheetId = '1ZSZGAtYyGasHIbeCZYBvnN-Xv46hUs6-u5Larbqb0ag'
codebook_data_range = 'Teads Codebook!A3:J1000'

output_spreadsheetId = '1ZSZGAtYyGasHIbeCZYBvnN-Xv46hUs6-u5Larbqb0ag'
output_data_range = 'Teads Results'

# %%
authenticator = Authenticator(keys)
creds = authenticator.get_creds(SCOPES)
manager = SheetManager(creds)

# %%
data_df = manager.get_values(spreadsheetId=data_spreadsheetId,
                        data_range=data_data_range)

codebook_df = manager.get_values(spreadsheetId=codebook_spreadsheetId,
                                data_range=codebook_data_range)

# %%
data_df.columns
# Out:
# Index(['SAMPLEID', 'ANSWERDATE', 'SEX', 'AGE', 'AGEID', 'PREFECTURE', 'AREA',
#        'MARRIED', 'CHILD', 'HINCOME', 'PINCOME', 'JOB', 'CELL', 'CELLNAME',
#        'Q1', 'Q2', 'Q3', 'Q4', 'Q5_1', 'Q5_2', 'Q5_3', 'Q5_4', 'Q6_1', 'Q6_2',
#        'Q6_3', 'Q6_4', 'Q6_5', 'Q6_6', 'Q6_7', 'Q7', 'Q8_1', 'Q8_2', 'Q8_3',
#        'Q8_4', 'Q8_5', 'Q8_6', 'Q9'],
#       dtype='object')

# %%
cb_df = codebook_df.copy()

cb_df.replace('', np.nan, inplace=True)

# create new column to indicate question or answer
cb_df['Q/A'] = np.nan
cb_df.loc[~cb_df['Item name'].isna(), 'Q/A'] = 'Q'
cb_df.loc[cb_df['Q/A'] != 'Q', 'Q/A'] = 'A'

# we really only need Item name, label, Choice number, Question / choices, Q/A
cols = ['Item name', 'label', 'Choice number', 'Question / choices', 'Q/A']
cb_df = cb_df[cols]

cb_df['Item name'] = cb_df['Item name'].fillna(method='ffill')

cb_df.loc[~cb_df['Item name'].isna() & cb_df['label'].isna(), 'label'] = cb_df['Item name']

#cb_df[~cb_df['Item name'].isna() & cb_df['label'].isna()]
cb_df
# Out:
#       Item name       label  Choice number  \
# 0      SAMPLEID    SAMPLEID            NaN
# 1    ANSWERDATE  ANSWERDATE            NaN
# 2           SEX         SEX            NaN
# 3           SEX         SEX            1.0
# 4           SEX         SEX            2.0
# 5           AGE         AGE            NaN
# 6         AGEID       AGEID            NaN
# 7         AGEID       AGEID            1.0
# 8         AGEID       AGEID            2.0
# 9         AGEID       AGEID            3.0
# 10        AGEID       AGEID            4.0
# 11        AGEID       AGEID            5.0
# 12        AGEID       AGEID            6.0
# 13        AGEID       AGEID            7.0
# 14        AGEID       AGEID            8.0
# 15        AGEID       AGEID            9.0
# 16        AGEID       AGEID           10.0
# 17        AGEID       AGEID           11.0
# 18   PREFECTURE  PREFECTURE            NaN
# 19   PREFECTURE  PREFECTURE            1.0
# 20   PREFECTURE  PREFECTURE            2.0
# 21   PREFECTURE  PREFECTURE            3.0
# 22   PREFECTURE  PREFECTURE            4.0
# 23   PREFECTURE  PREFECTURE            5.0
# 24   PREFECTURE  PREFECTURE            6.0
# 25   PREFECTURE  PREFECTURE            7.0
# 26   PREFECTURE  PREFECTURE            8.0
# 27   PREFECTURE  PREFECTURE            9.0
# 28   PREFECTURE  PREFECTURE           10.0
# 29   PREFECTURE  PREFECTURE           11.0
# ..          ...         ...            ...
# 161          Q6          Q6            NaN
# 162          Q6        Q6_1            1.0
# 163          Q6        Q6_2            2.0
# 164          Q6        Q6_3            3.0
# 165          Q6        Q6_4            4.0
# 166          Q6        Q6_5            5.0
# 167          Q6        Q6_6            6.0
# 168          Q6        Q6_7            7.0
# 169          Q7          Q7            NaN
# 170          Q7          Q7            1.0
# 171          Q7          Q7            2.0
# 172          Q7          Q7            3.0
# 173          Q7          Q7            4.0
# 174          Q7          Q7            5.0
# 175          Q7          Q7            6.0
# 176          Q8          Q8            NaN
# 177          Q8        Q8_1            1.0
# 178          Q8        Q8_2            2.0
# 179          Q8        Q8_3            3.0
# 180          Q8        Q8_4            4.0
# 181          Q8        Q8_5            5.0
# 182          Q8        Q8_6            6.0
# 183          Q9          Q9            NaN
# 184          Q9          Q9            1.0
# 185          Q9          Q9            2.0
# 186          Q9          Q9            3.0
# 187          Q9          Q9            4.0
# 188          Q9          Q9            5.0
# 189          Q9          Q9            6.0
# 190          Q9          Q9            7.0
#
#                                    Question / choices Q/A
# 0                                               回答者ID   Q
# 1                                                回答日時   Q
# 2                                                  性別   Q
# 3                                                  男性   A
# 4                                                  女性   A
# 5                                               年齢(才)   Q
# 6                                                  年齢   Q
# 7                                               12才未満   A
# 8                                             12才～19才   A
# 9                                             20才～24才   A
# 10                                            25才～29才   A
# 11                                            30才～34才   A
# 12                                            35才～39才   A
# 13                                            40才～44才   A
# 14                                            45才～49才   A
# 15                                            50才～54才   A
# 16                                            55才～59才   A
# 17                                              60才以上   A
# 18                                               都道府県   Q
# 19                                                北海道   A
# 20                                                青森県   A
# 21                                                岩手県   A
# 22                                                宮城県   A
# 23                                                秋田県   A
# 24                                                山形県   A
# 25                                                福島県   A
# 26                                                茨城県   A
# 27                                                栃木県   A
# 28                                                群馬県   A
# 29                                                埼玉県   A
# ..                                                ...  ..
# 161   次のうち、あなたが好きな広告プラットフォームはどれですか。あてはまるものを全てお選びください。   Q
# 162                                           YouTube   A
# 163                                          Facebook   A
# 164                                         Instagram   A
# 165                                               テレビ   A
# 166                                      Yahoo! JAPAN   A
# 167                                           Twitter   A
# 168                                        あてはまるものはない   A
# 169                       YouTubeにどの程度広告を掲載したいと思いますか。   Q
# 170                                           とてもそう思う   A
# 171                                              そう思う   A
# 172                                         どちらとも言えない   A
# 173                                            そう思わない   A
# 174                                        まったくそう思わない   A
# 175                                             わからない   A
# 176  YouTubeに広告を掲載したいと思わない理由はどれですか。あてはまるものを全てお選びください。   Q
# 177                                    金額が高い、ROIに合わない   A
# 178                                十分なリーチを獲得することができない   A
# 179                                ターゲットにリーチすることができない   A
# 180                                   広告キャンペーンの設定が難しい   A
# 181                                           広告効果が低い   A
# 182                                        あてはまるものはない   A
# 183                                   あなたの年齢をお答えください。   Q
# 184                                             18歳未満   A
# 185                                            18-24歳   A
# 186                                            25-34歳   A
# 187                                            35-44歳   A
# 188                                            45-54歳   A
# 189                                            55-64歳   A
# 190                                             65歳以上   A
#
# [191 rows x 5 columns]

# %%
questions = cb_df[['label', 'Question / choices']]
questions
# Out:
#           label                                Question / choices
# 0      SAMPLEID                                             回答者ID
# 1    ANSWERDATE                                              回答日時
# 2           SEX                                                性別
# 3           SEX                                                男性
# 4           SEX                                                女性
# 5           AGE                                             年齢(才)
# 6         AGEID                                                年齢
# 7         AGEID                                             12才未満
# 8         AGEID                                           12才～19才
# 9         AGEID                                           20才～24才
# 10        AGEID                                           25才～29才
# 11        AGEID                                           30才～34才
# 12        AGEID                                           35才～39才
# 13        AGEID                                           40才～44才
# 14        AGEID                                           45才～49才
# 15        AGEID                                           50才～54才
# 16        AGEID                                           55才～59才
# 17        AGEID                                             60才以上
# 18   PREFECTURE                                              都道府県
# 19   PREFECTURE                                               北海道
# 20   PREFECTURE                                               青森県
# 21   PREFECTURE                                               岩手県
# 22   PREFECTURE                                               宮城県
# 23   PREFECTURE                                               秋田県
# 24   PREFECTURE                                               山形県
# 25   PREFECTURE                                               福島県
# 26   PREFECTURE                                               茨城県
# 27   PREFECTURE                                               栃木県
# 28   PREFECTURE                                               群馬県
# 29   PREFECTURE                                               埼玉県
# ..          ...                                               ...
# 161          Q6   次のうち、あなたが好きな広告プラットフォームはどれですか。あてはまるものを全てお選びください。
# 162        Q6_1                                           YouTube
# 163        Q6_2                                          Facebook
# 164        Q6_3                                         Instagram
# 165        Q6_4                                               テレビ
# 166        Q6_5                                      Yahoo! JAPAN
# 167        Q6_6                                           Twitter
# 168        Q6_7                                        あてはまるものはない
# 169          Q7                       YouTubeにどの程度広告を掲載したいと思いますか。
# 170          Q7                                           とてもそう思う
# 171          Q7                                              そう思う
# 172          Q7                                         どちらとも言えない
# 173          Q7                                            そう思わない
# 174          Q7                                        まったくそう思わない
# 175          Q7                                             わからない
# 176          Q8  YouTubeに広告を掲載したいと思わない理由はどれですか。あてはまるものを全てお選びください。
# 177        Q8_1                                    金額が高い、ROIに合わない
# 178        Q8_2                                十分なリーチを獲得することができない
# 179        Q8_3                                ターゲットにリーチすることができない
# 180        Q8_4                                   広告キャンペーンの設定が難しい
# 181        Q8_5                                           広告効果が低い
# 182        Q8_6                                        あてはまるものはない
# 183          Q9                                   あなたの年齢をお答えください。
# 184          Q9                                             18歳未満
# 185          Q9                                            18-24歳
# 186          Q9                                            25-34歳
# 187          Q9                                            35-44歳
# 188          Q9                                            45-54歳
# 189          Q9                                            55-64歳
# 190          Q9                                             65歳以上
#
# [191 rows x 2 columns]

# %% [markdown]
# Create "Overall" for Awareness

# %%
data_df['Q5'] = 0
data_df.loc[(data_df['Q5_1'] == 1) | (data_df['Q5_2'] == 1) | (data_df['Q5_3'] == 1), 'Q5'] = 1

# %%
recode_dic = {
    'Q2': [1, 2],
    'Q3': [1, 2],
    'Q4': [1, 2],
    'Q5': [1],
    'Q5_1': [1],
    'Q5_2': [1],
    'Q5_3': [1],
    'Q6_1': [1],
    'Q7': [1, 2],
    'Q8_1': [1],
    'Q8_2': [1],
    'Q8_3': [1],
    'Q8_4': [1],
    'Q8_5': [1],
}

def recode(df):
    for q in recode_dic.keys():
        df[q+'_r'] = 0
        df.loc[df[q].isin(recode_dic[q]), q+'_r'] = 1

# %%
overall_df = data_df.copy()

questions_to_recode = recode_dic.keys()

recode(overall_df)

overall_df['group'] = np.nan
overall_df.loc[overall_df['CELL'] <= 8, 'group'] = 'EXP'
overall_df.loc[overall_df['CELL'] >= 9, 'group'] = 'CON'

cuts_dic = {
    'Overall': overall_df
}

# %%
male_df = overall_df[overall_df['SEX'] == 1]
female_df = overall_df[overall_df['SEX'] == 2]

age25_34_df = overall_df[(overall_df['AGE'] >= 25) & (overall_df['AGE'] <= 34)]
age35_44_df = overall_df[(overall_df['AGE'] >= 35) & (overall_df['AGE'] <= 44)]
age45_54_df = overall_df[(overall_df['AGE'] >= 45) & (overall_df['AGE'] <= 54)]
age55_64_df = overall_df[(overall_df['AGE'] >= 55) & (overall_df['AGE'] <= 64)]

tokyo_osaka_df = overall_df[(overall_df['PREFECTURE'] == 13) | (overall_df['PREFECTURE'] == 27)]
excl_tokyo_osaka_df = overall_df[(overall_df['PREFECTURE'] != 13) & (overall_df['PREFECTURE'] != 27)]

nobarriers_df = overall_df[overall_df['Q8_6'] == 1]

usageintent_df = overall_df[overall_df['Q7'].isin([1, 2])]

cuts_dic['Male'] = male_df
cuts_dic['Female'] = female_df
cuts_dic['25-34'] = age25_34_df
cuts_dic['35-44'] = age35_44_df
cuts_dic['45-54'] = age45_54_df
cuts_dic['55-64'] = age55_64_df
cuts_dic['Tokyo + Osaka'] = tokyo_osaka_df
cuts_dic['Other Prefectures'] = excl_tokyo_osaka_df
cuts_dic['No Barriers'] = nobarriers_df
cuts_dic['Usage Intent'] = usageintent_df

# %%
output = pd.DataFrame()
for cut in cuts_dic.keys():
    df = cuts_dic[cut]

    df = df[[*[q+'_r' for q in questions_to_recode], 'group']]

    con_base = len(df[df['group'] == 'CON'])
    exp_base = len(df[df['group'] == 'EXP'])

    df = df.groupby('group').sum().transpose()
    df['CON_base'] = con_base
    df['EXP_base'] = exp_base

    df['CON_desired_%'] = df['CON']/df['CON_base']
    df['EXP_desired_%'] = df['EXP']/df['EXP_base']

    df['abs_lift_%'] = df['EXP_desired_%'] - df['CON_desired_%']

    df['p-value'] = df.apply(lambda x: ztest(
                                            [x['EXP'], x['CON']],
                                            [x['EXP_base'], x['CON_base']])[1], axis = 1)
    df['Cut'] = cut
    
    if output.empty:
        output = df
    else:
        output = pd.concat([output, df])
print(output)
# Out:
# group   CON  EXP  CON_base  EXP_base  CON_desired_%  EXP_desired_%  \
# Q2_r     73   75       362       362       0.201657       0.207182
# Q3_r     58   64       362       362       0.160221       0.176796
# Q4_r     94  100       362       362       0.259669       0.276243
# Q5_r    114  117       362       362       0.314917       0.323204
# Q5_1_r   43   42       362       362       0.118785       0.116022
# Q5_2_r   53   54       362       362       0.146409       0.149171
# Q5_3_r   54   57       362       362       0.149171       0.157459
# Q6_1_r  130  134       362       362       0.359116       0.370166
# Q7_r     61   55       362       362       0.168508       0.151934
# Q8_1_r   19   19       362       362       0.052486       0.052486
# Q8_2_r   13   14       362       362       0.035912       0.038674
# Q8_3_r   26   22       362       362       0.071823       0.060773
# Q8_4_r   21   16       362       362       0.058011       0.044199
# Q8_5_r   36   50       362       362       0.099448       0.138122
# Q2_r     50   40       181       181       0.276243       0.220994
# Q3_r     36   43       181       181       0.198895       0.237569
# Q4_r     58   55       181       181       0.320442       0.303867
# Q5_r     60   71       181       181       0.331492       0.392265
# Q5_1_r   34   37       181       181       0.187845       0.204420
# Q5_2_r   16   22       181       181       0.088398       0.121547
# Q5_3_r   37   38       181       181       0.204420       0.209945
# Q6_1_r   78   76       181       181       0.430939       0.419890
# Q7_r     41   33       181       181       0.226519       0.182320
# Q8_1_r    9   12       181       181       0.049724       0.066298
# Q8_2_r    5    8       181       181       0.027624       0.044199
# Q8_3_r   13   10       181       181       0.071823       0.055249
# Q8_4_r   10   11       181       181       0.055249       0.060773
# Q8_5_r   21   29       181       181       0.116022       0.160221
# Q2_r     23   35       181       181       0.127072       0.193370
# Q3_r     22   21       181       181       0.121547       0.116022
# ...     ...  ...       ...       ...            ...            ...
# Q8_4_r   13    7       200       212       0.065000       0.033019
# Q8_5_r   18   23       200       212       0.090000       0.108491
# Q2_r      5    1       104        90       0.048077       0.011111
# Q3_r      2    2       104        90       0.019231       0.022222
# Q4_r     14   11       104        90       0.134615       0.122222
# Q5_r     21   15       104        90       0.201923       0.166667
# Q5_1_r    4    3       104        90       0.038462       0.033333
# Q5_2_r   13    9       104        90       0.125000       0.100000
# Q5_3_r    7    6       104        90       0.067308       0.066667
# Q6_1_r   20   14       104        90       0.192308       0.155556
# Q7_r      0    0       104        90       0.000000       0.000000
# Q8_1_r    0    0       104        90       0.000000       0.000000
# Q8_2_r    0    0       104        90       0.000000       0.000000
# Q8_3_r    0    0       104        90       0.000000       0.000000
# Q8_4_r    0    0       104        90       0.000000       0.000000
# Q8_5_r    0    0       104        90       0.000000       0.000000
# Q2_r     50   48        61        55       0.819672       0.872727
# Q3_r     34   40        61        55       0.557377       0.727273
# Q4_r     38   40        61        55       0.622951       0.727273
# Q5_r     39   34        61        55       0.639344       0.618182
# Q5_1_r   18   17        61        55       0.295082       0.309091
# Q5_2_r   17   15        61        55       0.278689       0.272727
# Q5_3_r   22   20        61        55       0.360656       0.363636
# Q6_1_r   51   48        61        55       0.836066       0.872727
# Q7_r     61   55        61        55       1.000000       1.000000
# Q8_1_r    0    0        61        55       0.000000       0.000000
# Q8_2_r    0    0        61        55       0.000000       0.000000
# Q8_3_r    0    0        61        55       0.000000       0.000000
# Q8_4_r    0    0        61        55       0.000000       0.000000
# Q8_5_r    0    0        61        55       0.000000       0.000000
#
# group   abs_lift_%   p-value                Cut
# Q2_r      0.005525  0.853768            Overall
# Q3_r      0.016575  0.551362            Overall
# Q4_r      0.016575  0.614627            Overall
# Q5_r      0.008287  0.810951            Overall
# Q5_1_r   -0.002762  0.908085            Overall
# Q5_2_r    0.002762  0.916597            Overall
# Q5_3_r    0.008287  0.756975            Overall
# Q6_1_r    0.011050  0.757435            Overall
# Q7_r     -0.016575  0.543247            Overall
# Q8_1_r    0.000000  1.000000            Overall
# Q8_2_r    0.002762  0.844499            Overall
# Q8_3_r   -0.011050  0.550176            Overall
# Q8_4_r   -0.013812  0.398759            Overall
# Q8_5_r    0.038674  0.107793            Overall
# Q2_r     -0.055249  0.223969               Male
# Q3_r      0.038674  0.373075               Male
# Q4_r     -0.016575  0.733646               Male
# Q5_r      0.060773  0.228934               Male
# Q5_1_r    0.016575  0.691294               Male
# Q5_2_r    0.033149  0.303562               Male
# Q5_3_r    0.005525  0.896817               Male
# Q6_1_r   -0.011050  0.831628               Male
# Q7_r     -0.044199  0.297118               Male
# Q8_1_r    0.016575  0.499987               Male
# Q8_2_r    0.016575  0.396769               Male
# Q8_3_r   -0.016575  0.518010               Male
# Q8_4_r    0.005525  0.822106               Male
# Q8_5_r    0.044199  0.222974               Male
# Q2_r      0.066298  0.085536             Female
# Q3_r     -0.005525  0.870950             Female
# ...            ...       ...                ...
# Q8_4_r   -0.031981  0.131141  Other Prefectures
# Q8_5_r    0.018491  0.530910  Other Prefectures
# Q2_r     -0.036966  0.138035        No Barriers
# Q3_r      0.002991  0.883746        No Barriers
# Q4_r     -0.012393  0.797236        No Barriers
# Q5_r     -0.035256  0.528736        No Barriers
# Q5_1_r   -0.005128  0.848525        No Barriers
# Q5_2_r   -0.025000  0.583932        No Barriers
# Q5_3_r   -0.000641  0.985792        No Barriers
# Q6_1_r   -0.036752  0.501926        No Barriers
# Q7_r      0.000000       NaN        No Barriers
# Q8_1_r    0.000000       NaN        No Barriers
# Q8_2_r    0.000000       NaN        No Barriers
# Q8_3_r    0.000000       NaN        No Barriers
# Q8_4_r    0.000000       NaN        No Barriers
# Q8_5_r    0.000000       NaN        No Barriers
# Q2_r      0.053055  0.430668       Usage Intent
# Q3_r      0.169896  0.057282       Usage Intent
# Q4_r      0.104322  0.231932       Usage Intent
# Q5_r     -0.021162  0.813714       Usage Intent
# Q5_1_r    0.014009  0.869624       Usage Intent
# Q5_2_r   -0.005961  0.942817       Usage Intent
# Q5_3_r    0.002981  0.973393       Usage Intent
# Q6_1_r    0.036662  0.577185       Usage Intent
# Q7_r      0.000000       NaN       Usage Intent
# Q8_1_r    0.000000       NaN       Usage Intent
# Q8_2_r    0.000000       NaN       Usage Intent
# Q8_3_r    0.000000       NaN       Usage Intent
# Q8_4_r    0.000000       NaN       Usage Intent
# Q8_5_r    0.000000       NaN       Usage Intent
#
# [154 rows x 9 columns]
# C:\Users\charles.tan\Anaconda3\lib\site-packages\statsmodels\stats\weightstats.py:670: RuntimeWarning: invalid value encountered in double_scalars
#   zstat = value / std_diff
# C:\Users\charles.tan\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\charles.tan\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\charles.tan\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1831: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
#output = overall_df.reset_index()
#print(output)
#values = overall_df.columns.to_list()
#values.extend(output.values)

#values


#manager.update_values(spreadsheetId=output_spreadsheetId,
#                     update_range=output_data_range,
#                     values=values)

# %%
output.to_csv('output.csv')

# %%
nobarriers_df['Q7'].value_counts()
# Out:
# 5    153
# 4     41
# Name: Q7, dtype: int64
