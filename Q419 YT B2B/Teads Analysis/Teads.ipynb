# %%
import numpy as np
import pandas as pd
from statsmodels.stats.proportion import proportions_ztest as ztest

from authentication.authenticator import Authenticator
from sheets.sheetmanager import SheetManager

# %%
keys = 'credentials.json'
SCOPES = ['https://www.googleapis.com/auth/drive']

data_spreadsheetId = '1ZSZGAtYyGasHIbeCZYBvnN-Xv46hUs6-u5Larbqb0ag'
data_data_range = 'Teads Data'

codebook_spreadsheetId = '1ZSZGAtYyGasHIbeCZYBvnN-Xv46hUs6-u5Larbqb0ag'
codebook_data_range = 'Teads Codebook!A3:J1000'

# %%
authenticator = Authenticator(keys)
creds = authenticator.get_creds(SCOPES)
manager = SheetManager(creds)

# %%
data_df = manager.get_values(spreadsheetId=data_spreadsheetId,
                        data_range=data_data_range)

codebook_df = manager.get_values(spreadsheetId=codebook_spreadsheetId,
                                data_range=codebook_data_range)

# %%
data_df
# Out:
#      SAMPLEID        ANSWERDATE  SEX  AGE  AGEID  PREFECTURE  AREA  MARRIED  \
# 0        9804  2019/12/28 10:41    1   56     10          14     3        2
# 1       55020  2019/12/27 20:42    1   50      9          14     3        1
# 2       56237  2019/12/28 22:59    1   63     11          27     5        1
# 3       74972  2019/12/27 20:39    1   64     11          13     3        2
# 4      199003  2019/12/27 21:32    1   60     11          23     4        2
# 5      213703  2019/12/28 13:16    2   48      8          13     3        1
# 6      219383   2019/12/29 0:36    2   47      8          14     3        2
# 7      221364  2019/12/28 21:34    2   34      5          23     4        1
# 8      254848   2019/12/29 9:03    2   45      8          28     5        1
# 9      286991  2019/12/28 21:57    2   39      6          14     3        1
# 10     287084   2019/12/29 7:00    2   46      8          40     8        1
# 11     289275  2019/12/27 19:54    1   36      6          40     8        1
# 12     292672  2019/12/27 20:21    1   57     10          13     3        2
# 13     297124  2019/12/28 18:50    1   35      6          28     5        2
# 14     303120  2019/12/27 23:50    2   39      6          12     3        1
# 15     317609   2019/12/29 0:01    1   49      8          13     3        2
# 16     332853  2019/12/28 19:45    2   34      5          27     5        2
# 17     502284  2019/12/28 20:20    2   45      8          13     3        2
# 18     516542  2019/12/28 16:35    2   44      7          27     5        1
# 19     519921  2019/12/28 16:22    1   53      9          13     3        2
# 20     528792  2019/12/28 21:50    1   63     11          14     3        2
# 21     529353  2019/12/28 21:56    2   55     10          14     3        1
# 22     540484  2019/12/29 13:56    2   36      6          23     4        2
# 23     587271  2019/12/27 19:56    1   56     10          13     3        2
# 24     633786  2019/12/27 19:41    1   52      9          27     5        2
# 25     650655   2019/12/28 1:12    2   42      7          27     5        2
# 26     671955  2019/12/27 20:37    1   49      8          14     3        2
# 27     673894  2019/12/27 21:46    1   52      9          27     5        2
# 28     676567  2019/12/28 20:55    1   39      6          23     4        2
# 29     685569  2019/12/28 10:50    1   59     10          23     4        1
# ..        ...               ...  ...  ...    ...         ...   ...      ...
# 694  23352399  2019/12/29 17:24    2   34      5          14     3        1
# 695  23360048  2019/12/28 11:04    1   46      8          14     3        2
# 696  23362389   2019/12/29 8:58    2   50      9          13     3        1
# 697  23416005  2019/12/27 22:16    2   27      4          27     5        1
# 698  23417660  2019/12/28 21:35    1   27      4          13     3        1
# 699  23444895  2019/12/27 22:21    1   35      6          23     4        2
# 700  23451588  2019/12/28 10:18    1   56     10          13     3        2
# 701  23467765  2019/12/29 17:29    1   28      4          28     5        2
# 702  23493033  2019/12/29 18:33    1   38      6          27     5        2
# 703  23622020  2019/12/29 18:09    2   25      4          23     4        1
# 704  23683701  2019/12/29 18:16    2   25      4          13     3        1
# 705  23745344  2019/12/28 23:29    2   26      4          13     3        1
# 706  23756133  2019/12/27 19:37    1   44      7          13     3        1
# 707  23756316  2019/12/28 20:13    2   29      4          14     3        2
# 708  23757716  2019/12/27 20:51    1   25      4          12     3        1
# 709  23762973  2019/12/29 19:45    2   29      4          27     5        1
# 710  23768101  2019/12/29 12:08    2   35      6          23     4        1
# 711  23768273  2019/12/28 22:13    1   36      6          14     3        2
# 712  23787257  2019/12/29 11:04    1   29      4          27     5        1
# 713  23830169  2019/12/27 19:43    2   41      7          13     3        2
# 714  23857922  2019/12/28 21:56    1   29      4          23     4        2
# 715  23870246   2019/12/29 2:38    1   33      5          13     3        1
# 716  23870949   2019/12/28 1:20    2   32      5          23     4        2
# 717  23902986  2019/12/28 17:32    1   31      5          14     3        2
# 718  23919814  2019/12/28 22:59    1   29      4          13     3        1
# 719  23925321  2019/12/28 18:39    2   33      5          13     3        2
# 720  23950544  2019/12/28 20:02    1   38      6          13     3        1
# 721  23950726  2019/12/27 19:50    2   29      4          14     3        1
# 722  24068623   2019/12/28 3:12    2   46      8          13     3        1
# 723  24090355  2019/12/28 22:23    2   39      6          23     4        2
#
#      CHILD HINCOME  ... Q6_6  Q6_7  Q7 Q8_1  Q8_2  Q8_3  Q8_4  Q8_5  Q8_6  Q9
# 0        1       3  ...    0     1   5    0     0     0     0     1     0   6
# 1        1       3  ...    0     1   6                                      5
# 2        1       2  ...    0     1   3                                      6
# 3        2       7  ...    0     0   5    0     0     0     0     1     0   6
# 4        2       3  ...    0     0   3                                      6
# 5        1       4  ...    1     0   5    0     0     0     0     0     1   5
# 6        2          ...    1     0   3                                      5
# 7        1       2  ...    0     1   5    1     1     0     1     0     0   3
# 8        1      10  ...    0     1   5    0     0     0     0     1     0   5
# 9        1          ...    0     1   5    0     0     0     0     0     1   4
# 10       1       3  ...    0     1   6                                      5
# 11       1       4  ...    0     1   3                                      4
# 12       2       4  ...    0     0   5    0     0     0     0     0     1   6
# 13       2       3  ...    0     1   2                                      4
# 14       1       5  ...    0     0   3                                      4
# 15       2       5  ...    0     1   5    0     0     0     0     0     1   5
# 16       2       4  ...    0     1   6                                      3
# 17       1       3  ...    0     0   6                                      5
# 18       1       2  ...    0     1   3                                      4
# 19       1       3  ...    0     1   5    0     0     0     0     0     1   5
# 20       2       3  ...    0     0   1                                      6
# 21       1       5  ...    0     0   5    1     1     0     1     0     0   6
# 22       2       6  ...    0     1   3                                      4
# 23       2       5  ...    0     0   5    0     0     0     0     0     1   6
# 24       1       3  ...    0     0   3                                      5
# 25       1       9  ...    0     1   5    0     0     0     0     0     1   4
# 26       2       5  ...    0     0   5    0     0     0     1     1     0   5
# 27       2       4  ...    0     0   4    0     0     1     1     1     0   5
# 28       2       4  ...    0     0   2                                      4
# 29       1       3  ...    0     1   6                                      6
# ..     ...     ...  ...  ...   ...  ..  ...   ...   ...   ...   ...   ...  ..
# 694      1          ...    0     0   4    1     0     1     0     0     0   3
# 695      2       3  ...    0     0   5    0     0     0     0     0     1   5
# 696      1       2  ...    0     1   5    0     0     0     0     0     1   5
# 697      1          ...    0     0   6                                      3
# 698      1       5  ...    1     0   1                                      3
# 699      2       2  ...    0     0   2                                      4
# 700      2       6  ...    0     0   2                                      6
# 701      1       4  ...    0     0   3                                      3
# 702      2       5  ...    0     0   2                                      4
# 703      1       3  ...    1     0   2                                      3
# 704      1       2  ...    0     0   2                                      3
# 705      1       2  ...    0     0   5    0     0     0     0     0     1   3
# 706      1       5  ...    1     0   2                                      4
# 707      1       5  ...    1     0   2                                      3
# 708      2       2  ...    1     0   5    1     0     0     0     0     0   3
# 709      1       2  ...    0     0   4    1     0     0     0     0     0   3
# 710      1      10  ...    0     0   4    0     0     0     0     1     0   4
# 711      1       5  ...    0     0   1                                      4
# 712      1       3  ...    0     0   2                                      3
# 713      2          ...    1     0   2                                      4
# 714      1       4  ...    0     0   2                                      3
# 715      1       3  ...    0     0   2                                      3
# 716      1       5  ...    0     0   5    0     0     0     0     0     1   3
# 717      1       4  ...    0     0   2                                      3
# 718      1       9  ...    0     0   3                                      3
# 719      2       7  ...    0     0   2                                      3
# 720      1          ...    0     1   5    0     1     0     0     1     0   4
# 721      1       3  ...    1     0   3                                      3
# 722      1       3  ...    0     1   5    0     0     0     0     1     0   5
# 723      1       3  ...    0     0   5    0     0     0     0     0     1   4
#
# [724 rows x 37 columns]

# %%
cb_df = codebook_df.copy()

cb_df.replace('', np.nan, inplace=True)

# create new column to indicate question or answer
cb_df['Q/A'] = np.nan
cb_df.loc[~cb_df['Item name'].isna(), 'Q/A'] = 'Q'
cb_df.loc[cb_df['Q/A'] != 'Q', 'Q/A'] = 'A'

# we really only need Item name, label, Choice number, Question / choices, Q/A
cols = ['Item name', 'label', 'Choice number', 'Question / choices', 'Q/A']
cb_df = cb_df[cols]

cb_df['Item name'] = cb_df['Item name'].fillna(method='ffill')

cb_df.loc[~cb_df['Item name'].isna() & cb_df['label'].isna(), 'label'] = cb_df['Item name']

#cb_df[~cb_df['Item name'].isna() & cb_df['label'].isna()]
cb_df
# Out:
#       Item name       label  Choice number  \
# 0      SAMPLEID    SAMPLEID            NaN
# 1    ANSWERDATE  ANSWERDATE            NaN
# 2           SEX         SEX            NaN
# 3           SEX         SEX            1.0
# 4           SEX         SEX            2.0
# 5           AGE         AGE            NaN
# 6         AGEID       AGEID            NaN
# 7         AGEID       AGEID            1.0
# 8         AGEID       AGEID            2.0
# 9         AGEID       AGEID            3.0
# 10        AGEID       AGEID            4.0
# 11        AGEID       AGEID            5.0
# 12        AGEID       AGEID            6.0
# 13        AGEID       AGEID            7.0
# 14        AGEID       AGEID            8.0
# 15        AGEID       AGEID            9.0
# 16        AGEID       AGEID           10.0
# 17        AGEID       AGEID           11.0
# 18   PREFECTURE  PREFECTURE            NaN
# 19   PREFECTURE  PREFECTURE            1.0
# 20   PREFECTURE  PREFECTURE            2.0
# 21   PREFECTURE  PREFECTURE            3.0
# 22   PREFECTURE  PREFECTURE            4.0
# 23   PREFECTURE  PREFECTURE            5.0
# 24   PREFECTURE  PREFECTURE            6.0
# 25   PREFECTURE  PREFECTURE            7.0
# 26   PREFECTURE  PREFECTURE            8.0
# 27   PREFECTURE  PREFECTURE            9.0
# 28   PREFECTURE  PREFECTURE           10.0
# 29   PREFECTURE  PREFECTURE           11.0
# ..          ...         ...            ...
# 161          Q6          Q6            NaN
# 162          Q6        Q6_1            1.0
# 163          Q6        Q6_2            2.0
# 164          Q6        Q6_3            3.0
# 165          Q6        Q6_4            4.0
# 166          Q6        Q6_5            5.0
# 167          Q6        Q6_6            6.0
# 168          Q6        Q6_7            7.0
# 169          Q7          Q7            NaN
# 170          Q7          Q7            1.0
# 171          Q7          Q7            2.0
# 172          Q7          Q7            3.0
# 173          Q7          Q7            4.0
# 174          Q7          Q7            5.0
# 175          Q7          Q7            6.0
# 176          Q8          Q8            NaN
# 177          Q8        Q8_1            1.0
# 178          Q8        Q8_2            2.0
# 179          Q8        Q8_3            3.0
# 180          Q8        Q8_4            4.0
# 181          Q8        Q8_5            5.0
# 182          Q8        Q8_6            6.0
# 183          Q9          Q9            NaN
# 184          Q9          Q9            1.0
# 185          Q9          Q9            2.0
# 186          Q9          Q9            3.0
# 187          Q9          Q9            4.0
# 188          Q9          Q9            5.0
# 189          Q9          Q9            6.0
# 190          Q9          Q9            7.0
#
#                                    Question / choices Q/A
# 0                                               回答者ID   Q
# 1                                                回答日時   Q
# 2                                                  性別   Q
# 3                                                  男性   A
# 4                                                  女性   A
# 5                                               年齢(才)   Q
# 6                                                  年齢   Q
# 7                                               12才未満   A
# 8                                             12才～19才   A
# 9                                             20才～24才   A
# 10                                            25才～29才   A
# 11                                            30才～34才   A
# 12                                            35才～39才   A
# 13                                            40才～44才   A
# 14                                            45才～49才   A
# 15                                            50才～54才   A
# 16                                            55才～59才   A
# 17                                              60才以上   A
# 18                                               都道府県   Q
# 19                                                北海道   A
# 20                                                青森県   A
# 21                                                岩手県   A
# 22                                                宮城県   A
# 23                                                秋田県   A
# 24                                                山形県   A
# 25                                                福島県   A
# 26                                                茨城県   A
# 27                                                栃木県   A
# 28                                                群馬県   A
# 29                                                埼玉県   A
# ..                                                ...  ..
# 161   次のうち、あなたが好きな広告プラットフォームはどれですか。あてはまるものを全てお選びください。   Q
# 162                                           YouTube   A
# 163                                          Facebook   A
# 164                                         Instagram   A
# 165                                               テレビ   A
# 166                                      Yahoo! JAPAN   A
# 167                                           Twitter   A
# 168                                        あてはまるものはない   A
# 169                       YouTubeにどの程度広告を掲載したいと思いますか。   Q
# 170                                           とてもそう思う   A
# 171                                              そう思う   A
# 172                                         どちらとも言えない   A
# 173                                            そう思わない   A
# 174                                        まったくそう思わない   A
# 175                                             わからない   A
# 176  YouTubeに広告を掲載したいと思わない理由はどれですか。あてはまるものを全てお選びください。   Q
# 177                                    金額が高い、ROIに合わない   A
# 178                                十分なリーチを獲得することができない   A
# 179                                ターゲットにリーチすることができない   A
# 180                                   広告キャンペーンの設定が難しい   A
# 181                                           広告効果が低い   A
# 182                                        あてはまるものはない   A
# 183                                   あなたの年齢をお答えください。   Q
# 184                                             18歳未満   A
# 185                                            18-24歳   A
# 186                                            25-34歳   A
# 187                                            35-44歳   A
# 188                                            45-54歳   A
# 189                                            55-64歳   A
# 190                                             65歳以上   A
#
# [191 rows x 5 columns]

# %%
questions = cb_df[['label', 'Question / choices']]
questions
# Out:
#           label                                Question / choices
# 0      SAMPLEID                                             回答者ID
# 1    ANSWERDATE                                              回答日時
# 2           SEX                                                性別
# 3           SEX                                                男性
# 4           SEX                                                女性
# 5           AGE                                             年齢(才)
# 6         AGEID                                                年齢
# 7         AGEID                                             12才未満
# 8         AGEID                                           12才～19才
# 9         AGEID                                           20才～24才
# 10        AGEID                                           25才～29才
# 11        AGEID                                           30才～34才
# 12        AGEID                                           35才～39才
# 13        AGEID                                           40才～44才
# 14        AGEID                                           45才～49才
# 15        AGEID                                           50才～54才
# 16        AGEID                                           55才～59才
# 17        AGEID                                             60才以上
# 18   PREFECTURE                                              都道府県
# 19   PREFECTURE                                               北海道
# 20   PREFECTURE                                               青森県
# 21   PREFECTURE                                               岩手県
# 22   PREFECTURE                                               宮城県
# 23   PREFECTURE                                               秋田県
# 24   PREFECTURE                                               山形県
# 25   PREFECTURE                                               福島県
# 26   PREFECTURE                                               茨城県
# 27   PREFECTURE                                               栃木県
# 28   PREFECTURE                                               群馬県
# 29   PREFECTURE                                               埼玉県
# ..          ...                                               ...
# 161          Q6   次のうち、あなたが好きな広告プラットフォームはどれですか。あてはまるものを全てお選びください。
# 162        Q6_1                                           YouTube
# 163        Q6_2                                          Facebook
# 164        Q6_3                                         Instagram
# 165        Q6_4                                               テレビ
# 166        Q6_5                                      Yahoo! JAPAN
# 167        Q6_6                                           Twitter
# 168        Q6_7                                        あてはまるものはない
# 169          Q7                       YouTubeにどの程度広告を掲載したいと思いますか。
# 170          Q7                                           とてもそう思う
# 171          Q7                                              そう思う
# 172          Q7                                         どちらとも言えない
# 173          Q7                                            そう思わない
# 174          Q7                                        まったくそう思わない
# 175          Q7                                             わからない
# 176          Q8  YouTubeに広告を掲載したいと思わない理由はどれですか。あてはまるものを全てお選びください。
# 177        Q8_1                                    金額が高い、ROIに合わない
# 178        Q8_2                                十分なリーチを獲得することができない
# 179        Q8_3                                ターゲットにリーチすることができない
# 180        Q8_4                                   広告キャンペーンの設定が難しい
# 181        Q8_5                                           広告効果が低い
# 182        Q8_6                                        あてはまるものはない
# 183          Q9                                   あなたの年齢をお答えください。
# 184          Q9                                             18歳未満
# 185          Q9                                            18-24歳
# 186          Q9                                            25-34歳
# 187          Q9                                            35-44歳
# 188          Q9                                            45-54歳
# 189          Q9                                            55-64歳
# 190          Q9                                             65歳以上
#
# [191 rows x 2 columns]

# %%
def recode_SA_A(question_list):
    for q in question_list:
        df[q+'_r'] = 0
        df.loc[((df[q] == 1) | (df[q] == 2)), q+'_r'] = 1

# %%
overall_df = data_df.copy()

questions_to_recode = ['Q2', 'Q3', 'Q4']

recode_SA_A(questions_to_recode) 

overall_df['group'] = np.nan
overall_df.loc[df['CELL'] <= 8, 'group'] = 'EXP'
overall_df.loc[df['CELL'] >= 9, 'group'] = 'CON'

df = df[[*[q+'_r' for q in questions_to_recode], 'group']]

cut_dfs = []
for cut 

con_base = len(df[df['group'] == 'CON'])
exp_base = len(df[df['group'] == 'EXP'])

df = df.groupby('group').sum().transpose()
df['CON_base'] = con_base
df['EXP_base'] = exp_base

df['CON_desired_%'] = df['CON']/df['CON_base']
df['EXP_desired_%'] = df['EXP']/df['EXP_base']

df['abs_lift_%'] = df['EXP_desired_%'] - df['CON_desired_%']

df['p-value'] = df.apply(lambda x: ztest(
                                        [x['EXP'], x['CON']],
                                        [x['EXP_base'], x['CON_base']])[1], axis = 1)

df
# Out:
# group  CON  EXP  CON_base  EXP_base  CON_desired_%  EXP_desired_%  abs_lift_%  \
# Q2_r    73   75       362       362       0.201657       0.207182    0.005525
# Q3_r    58   64       362       362       0.160221       0.176796    0.016575
# Q4_r    94  100       362       362       0.259669       0.276243    0.016575
#
# group   p-value
# Q2_r   0.853768
# Q3_r   0.551362
# Q4_r   0.614627

# %%
df.to_csv("result.csv")
